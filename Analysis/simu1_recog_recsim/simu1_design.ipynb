# %%
# randomly pick the existing design, self-generated semantic matrix
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# ### Load Real Design

# %%
df = pd.read_csv("simu1_data/cr_preproc_data_mturk.csv")
df
# Out:
#               rt  time_elapsed  subject_ID      item  lag       category  \
# 0       1640.345       71781.0         120       ARM    0  Uncategorized
# 1        845.750       71783.0         422     CELLO    0  Uncategorized
# 2            NaN       72233.0          52   HALLWAY    0       Building
# 3            NaN       72813.0          20  MOUNTAIN    0  Uncategorized
# 4            NaN       73029.0         108     ROBIN    0  Uncategorized
# ...          ...           ...         ...       ...  ...            ...
# 381055       NaN    12140412.0         228    CARROT  163     Vegetables
# 381056       NaN    12144498.0         228     GOOSE  112  Uncategorized
# 381057       NaN    12148572.0         228      PEAS   68     Vegetables
# 381058       NaN    12152653.0         228       SAW  159          Tools
# 381059       NaN    12156752.0         228   GIRAFFE  129            Zoo
#
#         confidence  correct  correct_num category_label  ... position    old  \
# 0              1.0     True            1      BodyParts  ...        0  False
# 1              5.0    False            0    Instruments  ...        0  False
# 2              NaN    False            0       Building  ...        0  False
# 3              NaN    False            0     Landscapes  ...        0  False
# 4              NaN    False            0          Birds  ...        0  False
# ...            ...      ...          ...            ...  ...      ...    ...
# 381055         NaN    False            0     Vegetables  ...      575   True
# 381056         NaN    False            0          Birds  ...      576   True
# 381057         NaN    False            0     Vegetables  ...      577   True
# 381058         NaN    False            0          Tools  ...      578   True
# 381059         NaN    False            0            Zoo  ...      579   True
#
#           yes     block_type       prev_cat prev_cat_match prev_cat_label  \
# 0       False  Uncategorized            NaN            NaN            NaN
# 1        True  Uncategorized            NaN            NaN            NaN
# 2         NaN    Categorized            NaN          False            NaN
# 3         NaN  Uncategorized            NaN            NaN            NaN
# 4         NaN  Uncategorized            NaN            NaN            NaN
# ...       ...            ...            ...            ...            ...
# 381055    NaN    Categorized     Landscapes          False     Landscapes
# 381056    NaN  Uncategorized     Vegetables            NaN     Vegetables
# 381057    NaN    Categorized  Uncategorized          False          Birds
# 381058    NaN    Categorized     Vegetables          False     Vegetables
# 381059    NaN    Categorized          Tools          False          Tools
#
#        prev_cat_label_match  curr_cat_length  curr_cat_label_length
# 0                     False              NaN                      0
# 1                     False              NaN                      0
# 2                     False              0.0                      0
# 3                     False              NaN                      0
# 4                     False              NaN                      0
# ...                     ...              ...                    ...
# 381055                False             20.0                     20
# 381056                False              NaN                     21
# 381057                False             21.0                     21
# 381058                False             22.0                     22
# 381059                False             22.0                     22
#
# [381060 rows x 21 columns]

# %%
# drop redundant columns
df = df.drop(
    [
        "rt",
        "time_elapsed",
        "correct",
        "correct_num",
        "block_type",
        "item_name",
        "prev_cat",
        "prev_cat_match",
        "prev_cat_label",
        "prev_cat_label_match",
        "curr_cat_length",
        "curr_cat_label_length",
        "confidence",
        "category",
    ],
    axis=1,
)
df
# Out:
#         subject_ID      item  lag category_label  position    old    yes
# 0              120       ARM    0      BodyParts         0  False  False
# 1              422     CELLO    0    Instruments         0  False   True
# 2               52   HALLWAY    0       Building         0  False    NaN
# 3               20  MOUNTAIN    0     Landscapes         0  False    NaN
# 4              108     ROBIN    0          Birds         0  False    NaN
# ...            ...       ...  ...            ...       ...    ...    ...
# 381055         228    CARROT  163     Vegetables       575   True    NaN
# 381056         228     GOOSE  112          Birds       576   True    NaN
# 381057         228      PEAS   68     Vegetables       577   True    NaN
# 381058         228       SAW  159          Tools       578   True    NaN
# 381059         228   GIRAFFE  129            Zoo       579   True    NaN
#
# [381060 rows x 7 columns]

# %%
# drop subjects with > 250 no responses
subjlist = df.subject_ID.to_numpy()
subjlist = np.unique(subjlist)
discard = []
for subj in subjlist:
    df_subj = df.loc[df.subject_ID == subj]
    no_ans = np.isnan(df_subj.yes.to_numpy().astype("float"))
    num_no_ans = np.sum(no_ans)
    if num_no_ans > 250:
        discard.append(subj)
discard.append(200)  # additional, see David
df = df.loc[df.subject_ID.isin(discard) == False].copy()
df.drop("yes", axis=1, inplace=True)

# %%
# how many subjects
subjlist = df.subject_ID.to_numpy()
subjlist = np.unique(subjlist)
len(subjlist)
# Out:
# 548

# %%
# add itemno
items = np.unique(df.item)
item2no = {}
for i in range(len(items)):
    item2no[items[i]] = i + 1
df["itemno"] = df.apply(lambda x: item2no[x.loc["item"]], 1)
df
# Out:
#         subject_ID      item  lag  category_label  position    old  itemno
# 4              108     ROBIN    0           Birds         0  False     220
# 6              536      WALL    0        Building         0  False     288
# 15             108    TURKEY    0     FarmAnimals         1  False     280
# 17             469    TABLET    0     Electronics         0  False     263
# 18             452  NOTEBOOK    0  OfficeSupplies         0  False     177
# ...            ...       ...  ...             ...       ...    ...     ...
# 381055         228    CARROT  163      Vegetables       575   True      43
# 381056         228     GOOSE  112           Birds       576   True     119
# 381057         228      PEAS   68      Vegetables       577   True     194
# 381058         228       SAW  159           Tools       578   True     228
# 381059         228   GIRAFFE  129             Zoo       579   True     115
#
# [317840 rows x 7 columns]

# %%
# organize
df = df.sort_values(by=["subject_ID", "position"])
df = df.reset_index(drop=True)
df = df[["subject_ID", "position", "item", "itemno", "category_label", "lag", "old"]]
df
# Out:
#         subject_ID  position       item  itemno category_label  lag    old
# 0                0         0    CHICKEN      53    FarmAnimals    0  False
# 1                0         1  BLUEBERRY      26          Fruit    0  False
# 2                0         2        BUS      33       Vehicles    0  False
# 3                0         3      LEMON     151          Fruit    0  False
# 4                0         4     OYSTER     187   OceanAnimals    0  False
# ...            ...       ...        ...     ...            ...  ...    ...
# 317835         656       575       COLA      60      Beverages   37   True
#        656,  16, 441,  94, 430, 412,  65, 453, 595, 576,  18, 161, 157,
#        295,  98, 570, 519, 539, 132,   8, 603, 189, 433, 602,  23,   2,
#          2, 106,  40, 550, 399, 645, 536, 634, 156, 187, 566, 161,  43,
#        445, 535, 638, 612,  83, 517, 564, 466, 550, 560, 289,  29, 296,
#        134,  79,  88, 466, 331, 354, 501, 359, 417,  63, 567, 291, 106,
#        543, 489,  41, 128,   9, 176,  70, 475, 342, 645, 503, 404, 334,
#         41,  51, 406,   2,  31, 144, 588, 301, 472, 267, 115, 243,  66,
#        516, 123, 247, 645, 389, 301, 356, 525, 166, 421, 582, 374, 289,
#        100, 163, 623, 355, 198, 271, 380, 352, 467, 169, 429, 287, 620,
#        107, 102, 302, 333, 461, 263, 604, 311,  90,  83, 641,  93, 624,
#        181,  67, 199, 405, 277, 526, 403, 261, 420, 640, 267, 105, 266,
#        561, 143, 625, 386, 396, 209, 608,  23, 196, 271, 313, 311, 102,
#        147,  68, 374, 229, 370, 387, 468, 358, 429, 385, 431, 406, 209,
#        161, 527, 223, 359, 131, 279, 346, 415, 344, 235, 634, 335])

# %%
df_test = pd.DataFrame()
for i in range(len(sess)):
    tmp = df.loc[df.subject_ID == sess[i], :].copy()
    tmp["session"] = i
    df_test = pd.concat([df_test, tmp])
df_test = df_test.reset_index(drop=True)
df_test["study_itemno1"] = df_test["itemno"]
df_test["study_itemno2"] = -1
df_test["test_itemno1"] = df_test["itemno"]
df_test["test_itemno2"] = -1
df_test
# Out:
#         subject_ID  position       item  itemno  category_label  lag    old  \
# 0               64         0     ERASER      96  OfficeSupplies    0  False
# 1               64         1        PEN     196  OfficeSupplies    0  False
# 2               64         2     PENCIL     197  OfficeSupplies    0  False
# 3               64         3        VAN     285        Vehicles    0  False
# 4               64         4    LETTUCE     153      Vegetables    0  False
# ...            ...       ...        ...     ...             ...  ...    ...
# 579995         335       575      PAPER     190  OfficeSupplies    0  False
# 579996         335       576       FORK     110    KitchenTools    0  False
# 579997         335       577   NOTEBOOK     177  OfficeSupplies    0  False
# 579998         335       578  DOLLHOUSE      81            Toys    0  False
# 579999         335       579     SLINKY     241            Toys    0  False
#
#         session  study_itemno1  study_itemno2  test_itemno1  test_itemno2
# 0             0             96             -1            96            -1
# 1             0            196             -1           196            -1
# 2             0            197             -1           197            -1
# 3             0            285             -1           285            -1
# 4             0            153             -1           153            -1
# ...         ...            ...            ...           ...           ...
# 579995      999            190             -1           190            -1
# 579996      999            110             -1           110            -1
# 579997      999            177             -1           177            -1
# 579998      999             81             -1            81            -1
# 579999      999            241             -1           241            -1
#
# [580000 rows x 12 columns]

# %%
# save
with open("simu1_data/simu1_design.pkl", "wb") as outp:
    pickle.dump(df_test, outp, pickle.HIGHEST_PROTOCOL)
