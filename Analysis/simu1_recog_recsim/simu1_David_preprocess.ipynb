# %%
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# ## Initial Inspection

# %%
df = pd.read_csv("simu1_data/cr_preproc_data_mturk.csv")
df
# Out:
#               rt  time_elapsed  subject_ID      item  lag       category  \
# 0       1640.345       71781.0         120       ARM    0  Uncategorized
# 1        845.750       71783.0         422     CELLO    0  Uncategorized
# 2            NaN       72233.0          52   HALLWAY    0       Building
# 3            NaN       72813.0          20  MOUNTAIN    0  Uncategorized
# 4            NaN       73029.0         108     ROBIN    0  Uncategorized
# ...          ...           ...         ...       ...  ...            ...
# 381055       NaN    12140412.0         228    CARROT  163     Vegetables
# 381056       NaN    12144498.0         228     GOOSE  112  Uncategorized
# 381057       NaN    12148572.0         228      PEAS   68     Vegetables
# 381058       NaN    12152653.0         228       SAW  159          Tools
# 381059       NaN    12156752.0         228   GIRAFFE  129            Zoo
#
#         confidence  correct  correct_num category_label  ... position    old  \
# 0              1.0     True            1      BodyParts  ...        0  False
# 1              5.0    False            0    Instruments  ...        0  False
# 2              NaN    False            0       Building  ...        0  False
# 3              NaN    False            0     Landscapes  ...        0  False
# 4              NaN    False            0          Birds  ...        0  False
# ...            ...      ...          ...            ...  ...      ...    ...
# 381055         NaN    False            0     Vegetables  ...      575   True
# 381056         NaN    False            0          Birds  ...      576   True
# 381057         NaN    False            0     Vegetables  ...      577   True
# 381058         NaN    False            0          Tools  ...      578   True
# 381059         NaN    False            0            Zoo  ...      579   True
#
#           yes     block_type       prev_cat prev_cat_match prev_cat_label  \
# 0       False  Uncategorized            NaN            NaN            NaN
# 1        True  Uncategorized            NaN            NaN            NaN
# 2         NaN    Categorized            NaN          False            NaN
# 3         NaN  Uncategorized            NaN            NaN            NaN
# 4         NaN  Uncategorized            NaN            NaN            NaN
# ...       ...            ...            ...            ...            ...
# 381055    NaN    Categorized     Landscapes          False     Landscapes
# 381056    NaN  Uncategorized     Vegetables            NaN     Vegetables
# 381057    NaN    Categorized  Uncategorized          False          Birds
# 381058    NaN    Categorized     Vegetables          False     Vegetables
# 381059    NaN    Categorized          Tools          False          Tools
#
#        prev_cat_label_match  curr_cat_length  curr_cat_label_length
# 0                     False              NaN                      0
# 1                     False              NaN                      0
# 2                     False              0.0                      0
# 3                     False              NaN                      0
# 4                     False              NaN                      0
# ...                     ...              ...                    ...
# 381055                False             20.0                     20
# 381056                False              NaN                     21
# 381057                False             21.0                     21
# 381058                False             22.0                     22
# 381059                False             22.0                     22
#
# [381060 rows x 21 columns]

# %%
df = df.drop(
    ["time_elapsed", "correct", "correct_num", "block_type", "item_name", "prev_cat", "prev_cat_match", "prev_cat_label", "prev_cat_label_match"], axis=1
)
df
# Out:
#               rt  subject_ID      item  lag       category  confidence  \
# 0       1640.345         120       ARM    0  Uncategorized         1.0
# 1        845.750         422     CELLO    0  Uncategorized         5.0
# 2            NaN          52   HALLWAY    0       Building         NaN
# 3            NaN          20  MOUNTAIN    0  Uncategorized         NaN
# 4            NaN         108     ROBIN    0  Uncategorized         NaN
# ...          ...         ...       ...  ...            ...         ...
# 381055       NaN         228    CARROT  163     Vegetables         NaN
# 381056       NaN         228     GOOSE  112  Uncategorized         NaN
# 381057       NaN         228      PEAS   68     Vegetables         NaN
# 381058       NaN         228       SAW  159          Tools         NaN
# 381059       NaN         228   GIRAFFE  129            Zoo         NaN
#
#        category_label  position    old    yes  curr_cat_length  \
# 0           BodyParts         0  False  False              NaN
# 1         Instruments         0  False   True              NaN
# 2            Building         0  False    NaN              0.0
# 3          Landscapes         0  False    NaN              NaN
# 4               Birds         0  False    NaN              NaN
# ...               ...       ...    ...    ...              ...
# 381055     Vegetables       575   True    NaN             20.0
# 381056          Birds       576   True    NaN              NaN
# 381057     Vegetables       577   True    NaN             21.0
# 381058          Tools       578   True    NaN             22.0
# 381059            Zoo       579   True    NaN             22.0
#
#         curr_cat_label_length
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0
# ...                       ...
# 381055                     20
# 381056                     21
# 381057                     21
# 381058                     22
# 381059                     22
#
# [381060 rows x 12 columns]

# %% [markdown]
# ## Discard subjects with no-resp > 250

# %%
subjlist = df.subject_ID.to_numpy()
subjlist = np.unique(subjlist)
discard = []
for subj in subjlist:
    df_subj = df.loc[df.subject_ID == subj]
    no_ans = np.isnan(df_subj.yes.to_numpy().astype("float"))
    num_no_ans = np.sum(no_ans)
    if num_no_ans > 250:
        discard.append(subj)

discard.append(200)  # additional, see David
len(discard)
# Out:
# 109

# %%
df_cl = df.loc[df.subject_ID.isin(discard) == False]
df_cl = df_cl.sort_values(by=["subject_ID", "position"])
df_cl = df_cl.astype({"yes": "float"})
df_cl
# Out:
#               rt  subject_ID       item  lag                 category  \
# 57307   1514.875           0    CHICKEN    0            Uncategorized
# 57766    853.505           0  BLUEBERRY    0            Uncategorized
# 58224    731.040           0        BUS    0            Uncategorized
# 58695    848.955           0      LEMON    0            Uncategorized
# 59159    643.880           0     OYSTER    0            Uncategorized
# ...          ...         ...        ...  ...                      ...
# 337333  1911.000         656       COLA   37                Beverages
# 337508  2358.000         656   BASEBALL  115                     Toys
# 337682  1239.000         656        TEA   24                Beverages
# 337870  1567.000         656      RADIO   41  Uncategorized-Singleton
# 338047  1355.000         656      FINCH   81                    Birds
#
#         confidence category_label  position    old  yes  curr_cat_length  \
# 57307          1.0    FarmAnimals         0  False  0.0              NaN
# 57766          1.0          Fruit         1  False  0.0              NaN
# 58224          1.0       Vehicles         2  False  0.0              NaN
# 58695          1.0          Fruit         3  False  0.0              NaN
# 59159          1.0   OceanAnimals         4  False  0.0              NaN
# ...            ...            ...       ...    ...  ...              ...
# 337333         2.0      Beverages       575   True  0.0             18.0
# 337508         8.0           Toys       576   True  1.0             23.0
# 337682         8.0      Beverages       577   True  1.0             19.0
# 337870         2.0    Electronics       578   True  0.0              NaN
# 338047         8.0          Birds       579   True  1.0             22.0
#
#         curr_cat_label_length
# 57307                       0
# 57766                       0
# 58224                       0
# 58695                       1
# 59159                       0
# ...                       ...
# 337333                     18
# 337508                     23
# 337682                     19
# 337870                     23
# 338047                     22
#
# [317840 rows x 12 columns]

# %% [markdown]
# ## YES dtype

# %%
# df_cl = df_cl.loc[np.logical_not(np.isnan(df_cl.yes))].reset_index()
df_cl = df_cl.astype({"yes": "Int32"})
df_cl
# Out:
#               rt  subject_ID       item  lag                 category  \
# 57307   1514.875           0    CHICKEN    0            Uncategorized
# 57766    853.505           0  BLUEBERRY    0            Uncategorized
# 58224    731.040           0        BUS    0            Uncategorized
# 58695    848.955           0      LEMON    0            Uncategorized
# 59159    643.880           0     OYSTER    0            Uncategorized
# ...          ...         ...        ...  ...                      ...
# 337333  1911.000         656       COLA   37                Beverages
# 337508  2358.000         656   BASEBALL  115                     Toys
# 337682  1239.000         656        TEA   24                Beverages
# 337870  1567.000         656      RADIO   41  Uncategorized-Singleton
# 338047  1355.000         656      FINCH   81                    Birds
#
#         confidence category_label  position    old  yes  curr_cat_length  \
# 57307          1.0    FarmAnimals         0  False    0              NaN
# 57766          1.0          Fruit         1  False    0              NaN
# 58224          1.0       Vehicles         2  False    0              NaN
# 58695          1.0          Fruit         3  False    0              NaN
# 59159          1.0   OceanAnimals         4  False    0              NaN
# ...            ...            ...       ...    ...  ...              ...
# 337333         2.0      Beverages       575   True    0             18.0
# 337508         8.0           Toys       576   True    1             23.0
# 337682         8.0      Beverages       577   True    1             19.0
# 337870         2.0    Electronics       578   True    0              NaN
# 338047         8.0          Birds       579   True    1             22.0
#
#         curr_cat_label_length
# 57307                       0
# 57766                       0
# 58224                       0
# 58695                       1
# 59159                       0
# ...                       ...
# 337333                     18
# 337508                     23
# 337682                     19
# 337870                     23
# 338047                     22
#
# [317840 rows x 12 columns]

# %% [markdown]
# ## Add columns

# %%
items = np.unique(df_cl.item)
item2no = {}
for i in range(len(items)):
    item2no[items[i]] = i + 1
df_cl["itemno"] = df_cl.apply(lambda x: item2no[x.loc["item"]], 1)
df_cl
# Out:
#               rt  subject_ID       item  lag                 category  \
# 57307   1514.875           0    CHICKEN    0            Uncategorized
# 57766    853.505           0  BLUEBERRY    0            Uncategorized
# 58224    731.040           0        BUS    0            Uncategorized
# 58695    848.955           0      LEMON    0            Uncategorized
# 59159    643.880           0     OYSTER    0            Uncategorized
# ...          ...         ...        ...  ...                      ...
# 337333  1911.000         656       COLA   37                Beverages
# 337508  2358.000         656   BASEBALL  115                     Toys
# 337682  1239.000         656        TEA   24                Beverages
# 337870  1567.000         656      RADIO   41  Uncategorized-Singleton
# 338047  1355.000         656      FINCH   81                    Birds
#
#         confidence category_label  position    old  yes  curr_cat_length  \
# 57307          1.0    FarmAnimals         0  False    0              NaN
# 57766          1.0          Fruit         1  False    0              NaN
# 58224          1.0       Vehicles         2  False    0              NaN
# 58695          1.0          Fruit         3  False    0              NaN
# 59159          1.0   OceanAnimals         4  False    0              NaN
# ...            ...            ...       ...    ...  ...              ...
# 337333         2.0      Beverages       575   True    0             18.0
# 337508         8.0           Toys       576   True    1             23.0
# 337682         8.0      Beverages       577   True    1             19.0
# 337870         2.0    Electronics       578   True    0              NaN
# 338047         8.0          Birds       579   True    1             22.0
#
#         curr_cat_label_length  itemno
# 57307                       0      53
# 57766                       0      26
# 58224                       0      33
# 58695                       1     151
# 59159                       0     187
# ...                       ...     ...
# 337333                     18      60
# 337508                     23      10
# 337682                     19     265
# 337870                     23     213
# 338047                     22      99
#
# [317840 rows x 13 columns]

# %%
subjlist_cl = df_cl.subject_ID
subjlist_cl = np.unique(subjlist_cl)
len(subjlist_cl)
# Out:
# 548

# %%
df_cl["session"] = df_cl.apply(lambda x: np.flatnonzero(np.asarray(subjlist_cl == x.loc["subject_ID"])).item(), 1)
df_cl = df_cl.reset_index(drop=True)
df_cl
# Out:
#               rt  subject_ID       item  lag                 category  \
# 0       1514.875           0    CHICKEN    0            Uncategorized
# 1        853.505           0  BLUEBERRY    0            Uncategorized
# 2        731.040           0        BUS    0            Uncategorized
# 3        848.955           0      LEMON    0            Uncategorized
# 4        643.880           0     OYSTER    0            Uncategorized
# ...          ...         ...        ...  ...                      ...
# 317835  1911.000         656       COLA   37                Beverages
# 317836  2358.000         656   BASEBALL  115                     Toys
# 317837  1239.000         656        TEA   24                Beverages
# 317838  1567.000         656      RADIO   41  Uncategorized-Singleton
# 317839  1355.000         656      FINCH   81                    Birds
#
#         confidence category_label  position    old  yes  curr_cat_length  \
# 0              1.0    FarmAnimals         0  False    0              NaN
# 1              1.0          Fruit         1  False    0              NaN
# 2              1.0       Vehicles         2  False    0              NaN
# 3              1.0          Fruit         3  False    0              NaN
# 4              1.0   OceanAnimals         4  False    0              NaN
# ...            ...            ...       ...    ...  ...              ...
# 317835         2.0      Beverages       575   True    0             18.0
# 317836         8.0           Toys       576   True    1             23.0
# 317837         8.0      Beverages       577   True    1             19.0
# 317838         2.0    Electronics       578   True    0              NaN
# 317839         8.0          Birds       579   True    1             22.0
#
#         curr_cat_label_length  itemno  session
# 0                           0      53        0
# 1                           0      26        0
# 2                           0      33        0
# 3                           1     151        0
# 4                           0     187        0
# ...                       ...     ...      ...
# 317835                     18      60      547
# 317836                     23      10      547
# 317837                     19     265      547
# 317838                     23     213      547
# 317839                     22      99      547
#
# [317840 rows x 14 columns]

# %%
# save
with open("simu1_data/simu1_behav.pkl", "wb") as outp:
    pickle.dump(df_cl, outp, pickle.HIGHEST_PROTOCOL)
