# %%
import numpy as np
import pickle
import pandas as pd
import CMR_IA as cmr
import sys
import scipy as sp
import matplotlib.pyplot as plt

sys.path.append("../../Modeling/fitting")
from optimization_utils import make_boundary, get_wmse
from object_funcs import anal_perform_S2

# %%
from matplotlib import font_manager

font_manager.fontManager.addfont("/home1/beigejin/Times.ttc")
plt.rc("font", family="serif", serif=["Times"])
plt.rcParams["mathtext.fontset"] = "custom"
plt.rcParams["mathtext.rm"] = "Times"

# plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = 16
SAVERES = True
SAVEFIG = False

# %% [markdown]
# ## Load Stimuli and Semantic Matrix

# %%
# association recognition - cued recall
with open("simuS2_data/simuS2_design.pkl", "rb") as inp:
    df_study = pickle.load(inp)
    df_test = pickle.load(inp)
# df_study = df_study.loc[df_study.session < 100]  # for testing
# df_test = df_test.loc[df_test.session < 100]

# %%
df_study
# Out:
#         study_itemno1  study_itemno2 study_item1  study_item2  pair_idx  list  \
# 0                 809           1001         LEG         PAGE        16     0
# 1                 489           1310       DOUGH        SIREN         2     0
# 2                1232            731    SANDWICH      ICEBERG        12     0
# 3                  96            259  BASKETBALL  CATERPILLAR         9     0
# 4                1232            731    SANDWICH      ICEBERG        12     0
# ...               ...            ...         ...          ...       ...   ...
# 134995           1480           1422        TOOL       SWITCH        62     2
# 134996           1166            613       RANCH      FUNERAL        70     2
# 134997           1480           1422        TOOL       SWITCH        62     2
# 134998           1166            613       RANCH      FUNERAL        70     2
# 134999           1480           1422        TOOL       SWITCH        62     2
#
#         session  subject
# ...

# %%
df_test
# Out:
#         test_itemno1  test_itemno2 test_item1  test_item2  correct_ans  \
# 0                454           943  DETECTIVE     NEPTUNE            0
# 1                329            -1      CLOVE        None            1
# 2               1084            -1     PLAQUE        None            1
# 3                484           671     DONKEY        GULL            0
# 4               1452            -1  TERRITORY        None            0
# ...              ...           ...        ...         ...          ...
# 107995           957           818       NOSE  LIEUTENANT            0
# 107996           954           347   NITROGEN     COLOGNE            1
# 107997           427            -1    CURTAIN        None            1
# 107998           820          1567  LIGHTNING     VILLAIN            0
# 107999           116           843     BEETLE      LONDON            1
#
#         pair_idx            type  test  list  session  subject
# ...

# %%
sem_mat = np.load("../wordpools/ltp_FR_similarity_matrix.npy")

# %% [markdown]
# ## Run CMR-IA

# %%
# define parameters
params = cmr.make_default_params()
params.update(learn_while_retrieving=True, use_new_context=True, use_flexible_thresh=True)

# pso results
_, _, what_to_fit = make_boundary(sim_name="S2")
optim_params = np.loadtxt("simuS2_data/S2_250602_200-100.txt")
for pname, pvalue in zip(what_to_fit, optim_params):
    params[pname] = pvalue
params
# Out:
# {'beta_enc': 0.681916,
#  'beta_rec': 0.5,
#  'beta_cue': 0.059027,
#  'beta_rec_post': 0.847821,
#  'beta_distract': 0.202137,
#  'beta_enc_inpair': -1,
#  'phi_s': 2,
#  'phi_d': 0.5,
#  's_fc': 0.36362,
#  's_cf': 0,
#  'kappa': 0.5,
#  'eta': 0.5,
#  'omega': 5,
#  'alpha': 1,
#  'lamb': 0.5,
#  'c_thresh': 0.5,
#  'c_thresh_itm': 1.087871,
#  'c_thresh_assoc': 1.086495,
#  'd_assoc': 0,
#  'rec_time_limit': 60000.0,
#  'dt': 10,
#  'nitems_in_accumulator': 50,
#  'max_recalls': 50,
#  'learn_while_retrieving': True,
#  'use_new_context': True,
#  'psi_s': 0,
#  'psi_c': 1,
#  'c_s': 0,
#  'thresh_sigma': 0.014342,
#  'ban_recall': None,
#  'use_var_enc': False,
#  'var_enc_p': None,
#  'bad_enc_ratio': None,
#  'recog_slope': 1,
#  'use_flexible_thresh': True,
#  'thresh_rate': 0.006015,
#  'thresh_kernel_len': 10,
#  'gamma_fc': 0.182376,
#  'gamma_cf': 0.5}

# %%
for key in what_to_fit:
    print(f"{key}: {params[key]:.3f}")
# Out:
# beta_enc: 0.682
# beta_cue: 0.059
# beta_rec_post: 0.848
# beta_distract: 0.202
# gamma_fc: 0.182
# s_fc: 0.364
# c_thresh_itm: 1.088
# c_thresh_assoc: 1.086
# thresh_sigma: 0.014
# thresh_rate: 0.006

# %%
if SAVERES:
    # run the model
    df_simu, f_in_acc, f_in_dif = cmr.run_success_multi_sess(params, df_study, df_test, sem_mat, mode="Recog-Recog")

    # merge to get more info
    df_simu["test"] = df_test["test"]
    df_simu = df_simu.merge(df_test, on=["session", "list", "test", "test_itemno1", "test_itemno2"])

    # save
    df_simu.to_pickle("simuS2_data/simuS2_result.pkl")
else:
    # load results
    with open("simuS2_data/simuS2_result.pkl", "rb") as inp:
        df_simu = pickle.load(inp)
df_simu
# Out:
# ...
# 100%|██████████| 300/300 [06:20<00:00,  1.27s/it]
# CMR Time: 380.594140291214
#         session  list  test_itemno1  test_itemno2  s_resp  s_rt      csim  \
# 0             0     0           454           943       0     0  0.339408
# 1             0     0           329            -1       1     0  0.768929
# 2             0     0          1084            -1       0     0  0.731562
# 3             0     0           484           671       0     0  0.634160
# 4             0     0          1452            -1       0     0  0.304732
# ...         ...   ...           ...           ...     ...   ...       ...
# 107995      299     2           957           818       0     0  0.533493
# 107996      299     2           954           347       1     0  0.784305
# 107997      299     2           427            -1       1     0  0.792893
# 107998      299     2           820          1567       0     0  0.585021
# 107999      299     2           116           843       0     0  0.697918
#
# ...

# %%
df_simu["position"] = np.tile(np.arange(360), 300)

old_csim_pos = df_simu.query("test_itemno2 == -1 and correct_ans == 1").groupby("position").csim.mean()
old_pos = np.unique(df_simu.query("correct_ans == 1").position.to_numpy())
new_csim_pos = df_simu.query("test_itemno2 == -1 and correct_ans == 0").groupby("position").csim.mean()
new_pos = np.unique(df_simu.query("correct_ans == 0").position.to_numpy())
cthresh_pos = df_simu.query("test_itemno2 == -1").groupby("position").thresh.mean()
pos = np.unique(df_simu.position.to_numpy())

plt.plot(old_pos, old_csim_pos, label="old")
plt.plot(new_pos, new_csim_pos, label="new")
plt.plot(pos, cthresh_pos, label="thresh")
plt.xlabel("Position")
plt.ylabel("Similarity Score")
plt.legend()
# plt.xlim(239, 350)
plt.show()

# %%
df_simu["position"] = np.tile(np.arange(360), 300)

old_csim_pos = df_simu.query("test_itemno2 != -1 and correct_ans == 1").groupby("position").csim.mean()
old_pos = np.unique(df_simu.query("correct_ans == 1").position.to_numpy())
new_csim_pos = df_simu.query("test_itemno2 != -1 and correct_ans == 0").groupby("position").csim.mean()
new_pos = np.unique(df_simu.query("correct_ans == 0").position.to_numpy())
cthresh_pos = df_simu.query("test_itemno2 != -1").groupby("position").thresh.mean()
pos = np.unique(df_simu.position.to_numpy())

plt.plot(old_pos, old_csim_pos, label="old")
plt.plot(new_pos, new_csim_pos, label="new")
plt.plot(pos, cthresh_pos, label="thresh")
plt.xlabel("Position")
plt.ylabel("Similarity Score")
plt.legend()
# plt.xlim(0, 200)
plt.show()

# %% [markdown]
# ## Analysis

# %%
# get correctness and condition
df_simu["correct"] = df_simu.s_resp == df_simu.correct_ans


def get_cond(x):
    this_type = x["type"]
    target = x["correct_ans"]
    if target == 1:
        if this_type == "Different_Item":
            return "Different_Item"
        elif this_type == "Item_Pair":
            return "Item_Pair"
        elif this_type == "Pair_Item":
            return "Pair_Item"
        elif this_type == "Same_Item":
            return "Same_Item"
        elif this_type == "Intact_Pair":
            return "Intact_Pair"
    elif target == 0:
        if this_type == "extra":
            return "NR_Lure"
        elif this_type == "Same_Item" or this_type == "Intact_Pair":
            return "Repeated_Lure"
        else:
            return "Discard"


df_simu["condition"] = df_simu.apply(get_cond, axis=1)
df_simu
# Out:
#         session  list  test_itemno1  test_itemno2  s_resp  s_rt      csim  \
# 0             0     0           454           943       0     0  0.339408
# 1             0     0           329            -1       1     0  0.768929
# 2             0     0          1084            -1       0     0  0.731562
# 3             0     0           484           671       0     0  0.634160
# 4             0     0          1452            -1       0     0  0.304732
# ...         ...   ...           ...           ...     ...   ...       ...
# 107995      299     2           957           818       0     0  0.533493
# 107996      299     2           954           347       1     0  0.784305
# 107997      299     2           427            -1       1     0  0.792893
# 107998      299     2           820          1567       0     0  0.585021
# 107999      299     2           116           843       0     0  0.697918
#
#           thresh  test test_item1  test_item2  correct_ans  pair_idx  \
# ...

# %%
subjects = np.unique(df_simu.subject)
stats = []
for subj in subjects:
    df_subj = df_simu.query(f"subject=={subj} and list % 3 != 0")  # discard first list
    stats_subj = anal_perform_S2(df_subj)
    stats.append(stats_subj)
stats_mean = np.nanmean(stats, axis=0)
stats_mean.round(2)
# Out:
# array([[0.8 , 0.73, 0.31],
#        [0.8 , 0.88, 0.6 ],
#        [0.93, 0.86, 0.69],
#        [0.79, 0.83, 0.77],
#        [0.93, 0.94, 0.75],
#        [0.14, 0.15, 0.62],
#        [0.14, 0.1 , 0.  ]])

# %%
stats_mean
# Out:
# array([[0.79544493, 0.72971597, 0.30598262],
#        [0.79999651, 0.88397507, 0.60129179],
#        [0.92539442, 0.86296934, 0.68742934],
#        [0.79247174, 0.82630964, 0.7685619 ],
#        [0.93194444, 0.94055556, 0.74997868],
#        [0.13767035, 0.15160333, 0.61870239],
#        [0.14294444, 0.102     , 0.        ]])

# %% [markdown]
# array([[0.77592172, 0.77486845, 0.26940755],
#        [0.78453437, 0.88043817, 0.60695663],
#        [0.87534055, 0.83378535, 0.63852395],
#        [0.78517665, 0.82253187, 0.81015222],
#        [0.87983333, 0.90566667, 0.81183312],
#        [0.09899792, 0.13064775, 0.61037954],
#        [0.09144444, 0.08816667, 0.        ]])

# %%
stats_se = np.array(sp.stats.sem(np.array(stats), axis=0, nan_policy="omit"))
stats_se.round(3)
# Out:
# array([[0.008, 0.008, 0.028],
#        [0.006, 0.005, 0.02 ],
#        [0.005, 0.007, 0.016],
#        [0.008, 0.007, 0.014],
#        [0.006, 0.006, 0.011],
#        [0.013, 0.013, 0.017],
#        [0.002, 0.002, 0.   ]])

# %%
ground_truth = np.array(
    [
        [0.82, 0.68, 0.26],  # diff item
        [0.82, 0.85, 0.64],  # item/pair
        [0.91, 0.85, 0.59],  # pair/item
        [0.81, 0.82, 0.86],  # same item
        [0.90, 0.92, 0.94],  # intact pair
        [0.07, 0.15, 0.54],  # repeated lure
        [0.07, 0.06, 0],  # non-repeated lure
    ]
)
ground_truth_se = np.array(
    [
        [0.020, 0.030, 0.10],  # diff item
        [0.016, 0.020, 0.12],  # item/pair
        [0.018, 0.021, 0.10],  # pair/item
        [0.017, 0.017, 0.03],  # same item
        [0.022, 0.019, 0.02],  # intact pair
        [0.014, 0.018, 0.12],  # repeated lure
        [0.009, 0.009, -1],  # non-repeated lure
    ]
)
err = np.sum(np.power(stats_mean - ground_truth, 2))
err
# Out:
# 0.0822593335965499

# %%
err = get_wmse(ground_truth, stats_mean, ground_truth_se)
err
# Out:
# 226.38948176272334

# %% [markdown]
# ### Plot

# %%
def plot_cond(xs, ys, yerrs, facecolor, edgecolor, label, width=0.25):
    plt.bar(
        x=xs,
        height=ys,
        width=width,
        facecolor=facecolor,
        edgecolor=edgecolor,
        label=label,
    )
    plt.errorbar(
        x=xs,
        y=ys,
        yerr=yerrs,
        fmt=" ",
        color="black",
        lw=2,
        capsize=5,
        capthick=2,
    )

# %%
fig, ax = plt.subplots(figsize=(12, 6))

base_xs = np.array([0, 2])
width = 0.1
space = 0.02

# diff item
plot_cond(
    xs=base_xs - 6.5 * space - 6.5 * width,
    ys=ground_truth[0, :2],
    yerrs=ground_truth_se[0, :2],
    facecolor="C0",
    edgecolor="C0",
    label="Diff Item (Data)",
    width=width,
)
plot_cond(
    xs=base_xs - 5.5 * space - 5.5 * width,
    ys=stats_mean[0, :2],
    yerrs=stats_se[0, :2],
    facecolor="None",
    edgecolor="C0",
    label="Diff Item (CMR-IA)",
    width=width,
)
# item/pair
plot_cond(
    xs=base_xs - 4.5 * space - 4.5 * width,
    ys=ground_truth[1, :2],
    yerrs=ground_truth_se[1, :2],
    facecolor="C1",
    edgecolor="C1",
    label="Item/Pair (Data)",
    width=width,
)
plot_cond(
    xs=base_xs - 3.5 * space - 3.5 * width,
    ys=stats_mean[1, :2],
    yerrs=stats_se[1, :2],
    facecolor="None",
    edgecolor="C1",
    label="Item/Pair (CMR-IA)",
    width=width,
)
# pair/item
plot_cond(
    xs=base_xs - 2.5 * space - 2.5 * width,
    ys=ground_truth[2, :2],
    yerrs=ground_truth_se[2, :2],
    facecolor="C2",
    edgecolor="C2",
    label="Pair/Item (Data)",
    width=width,
)
plot_cond(
    xs=base_xs - 1.5 * space - 1.5 * width,
    ys=stats_mean[2, :2],
    yerrs=stats_se[2, :2],
    facecolor="None",
    edgecolor="C2",
    label="Pair/Item (CMR-IA)",
    width=width,
)
# same item
plot_cond(
    xs=base_xs - 0.5 * space - 0.5 * width,
    ys=ground_truth[3, :2],
    yerrs=ground_truth_se[3, :2],
    facecolor="C3",
    edgecolor="C3",
    label="Same Item (Data)",
    width=width,
)
plot_cond(
    xs=base_xs + 0.5 * space + 0.5 * width,
    ys=stats_mean[3, :2],
    yerrs=stats_se[3, :2],
    facecolor="None",
    edgecolor="C3",
    label="Same Item (CMR-IA)",
    width=width,
)
# intact pair
plot_cond(
    xs=base_xs + 1.5 * space + 1.5 * width,
    ys=ground_truth[4, :2],
    yerrs=ground_truth_se[4, :2],
    facecolor="C4",
    edgecolor="C4",
    label="Intact Pair (Data)",
    width=width,
)
plot_cond(
    xs=base_xs + 2.5 * space + 2.5 * width,
    ys=stats_mean[4, :2],
    yerrs=stats_se[4, :2],
    facecolor="None",
    edgecolor="C4",
    label="Intact Pair (CMR-IA)",
    width=width,
)
# repeat lure
plot_cond(
    xs=base_xs + 3.5 * space + 3.5 * width,
    ys=ground_truth[5, :2],
    yerrs=ground_truth_se[5, :2],
    facecolor="C5",
    edgecolor="C5",
    label="Repeated Lure (Data)",
    width=width,
)
plot_cond(
    xs=base_xs + 4.5 * space + 4.5 * width,
    ys=stats_mean[5, :2],
    yerrs=stats_se[5, :2],
    facecolor="None",
    edgecolor="C5",
    label="Repeated Lure (CMR-IA)",
    width=width,
)
# non-repeated lure
plot_cond(
    xs=base_xs + 5.5 * space + 5.5 * width,
    ys=ground_truth[6, :2],
    yerrs=ground_truth_se[6, :2],
    facecolor="C6",
    edgecolor="C6",
    label="Non-Repeated Lure (Data)",
    width=width,
)
plot_cond(
    xs=base_xs + 6.5 * space + 6.5 * width,
    ys=stats_mean[6, :2],
    yerrs=stats_se[6, :2],
    facecolor="None",
    edgecolor="C6",
    label="Non-Repeated Lure (CMR-IA)",
    width=width,
)

# setting
plt.xticks(ticks=base_xs, labels=["Test 1", "Test 2"])
plt.yticks(np.arange(0, 1.1, 0.2))
plt.ylabel("HR")
plt.xlim(-1, 3)
plt.ylim(0, 1)
ax.spines[["right", "top"]].set_visible(False)
ax.tick_params(axis="y", direction="in")
ax.tick_params(axis="x", direction="in")

L = plt.legend(title=None, prop={"size": 14})
L.set_visible(False)

# if SAVEFIG:
#     ax.set(xlabel=None, ylabel=None)
#     plt.tick_params(labelbottom=False)
#     plt.savefig("simuS1_fig/simuS1_all.pdf")
plt.show()

# %%
fig2, ax2 = plt.subplots(figsize=(24, 2))
ax2.axis("off")
L = ax2.legend(*ax.get_legend_handles_labels(), loc="center", ncol=7, fontsize=24)
# if SAVEFIG:
#     plt.savefig("simuS1_fig/simuS1_all_legend.pdf")

# %%
fig, ax = plt.subplots(figsize=(12, 6))

base_xs = np.array([0, 2, 4, 6, 8, 10, 12])
width = 0.3
space = 0.06

# Test 1
plot_cond(
    xs=base_xs - 1.5 * space - 1.5 * width,
    ys=ground_truth[:, 0],
    yerrs=ground_truth_se[:, 0],
    facecolor="C0",
    edgecolor="C0",
    label="Test 1 (Data)",
    width=width,
)
plot_cond(
    xs=base_xs - 0.5 * space - 0.5 * width,
    ys=stats_mean[:, 0],
    yerrs=stats_se[:, 0],
    facecolor="None",
    edgecolor="C0",
    label="Test 1 (CMR-IA)",
    width=width,
)
# Test 2
plot_cond(
    xs=base_xs + 0.5 * space + 0.5 * width,
    ys=ground_truth[:, 1],
    yerrs=ground_truth_se[:, 1],
    facecolor="C1",
    edgecolor="C1",
    label="Test 2 (Data)",
    width=width,
)
plot_cond(
    xs=base_xs + 1.5 * space + 1.5 * width,
    ys=stats_mean[:, 1],
    yerrs=stats_se[:, 1],
    facecolor="None",
    edgecolor="C1",
    label="Test 2 (CMR-IA)",
    width=width,
)

# setting
plt.xticks(ticks=base_xs, labels=["Diff Item", "Item/Pair", "Pair/Item", "Same Item", "Intact Pair", "Repeated Lure", "Non-Repeated Lure"])
plt.yticks(np.arange(0, 1.1, 0.2))
plt.ylabel("HR")
plt.xlim(-1, 13)
plt.ylim(0, 1)
ax.spines[["right", "top"]].set_visible(False)
ax.tick_params(axis="y", direction="in")
ax.tick_params(axis="x", direction="in")

L = plt.legend(title=None, prop={"size": 14})
L.set_visible(False)

# if SAVEFIG:
#     ax.set(xlabel=None, ylabel=None)
#     plt.tick_params(labelbottom=False)
#     plt.savefig("simuS1_fig/simuS1_all.pdf")
plt.show()

# %%
fig2, ax2 = plt.subplots(figsize=(12, 2))
ax2.axis("off")
L = ax2.legend(*ax.get_legend_handles_labels(), loc="center", ncol=2, fontsize=24)
# if SAVEFIG:
#     plt.savefig("simuS1_fig/simuS1_all_legend.pdf")

# %%
# Test 1
y1_low, y1_high = 0.62, 1
y2_low, y2_high = 0, 0.18
range1 = y1_high - y1_low
range2 = y2_high - y2_low

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(6, 8), gridspec_kw={"height_ratios": [range1, range2], "hspace": 0.03})
fig.subplots_adjust(left=0.1, right=0.98, bottom=0.1, top=0.98)

base_xs = np.arange(2, 7)
base_xs_far = np.arange(2)
width = 0.1

# HR
plot_params = {
    "color": "C0",
    "fmt": "o",
    "markersize": 6,
    "markeredgewidth": 1.5,
    "elinewidth": 1.5,
    "capsize": 5,
    "capthick": 1.5,
}
ax1.errorbar(
    x=base_xs - width,
    y=ground_truth[:5, 0],
    yerr=ground_truth_se[:5, 0],
    **plot_params,
)
ax1.errorbar(
    x=base_xs + width,
    y=stats_mean[:5, 0],
    yerr=stats_se[:5, 0],
    markerfacecolor="white",
    **plot_params,
)

# FAR
ax2.errorbar(
    x=base_xs_far - width,
    y=ground_truth[7:4:-1, 0],
    yerr=ground_truth_se[7:4:-1, 0],
    **plot_params,
)
ax2.errorbar(
    x=base_xs_far + width,
    y=stats_mean[7:4:-1, 0],
    yerr=stats_se[7:4:-1, 0],
    markerfacecolor="white",
    **plot_params,
)

# ax2.axhspan(stats_mean[5, 0] + stats_se[5, 0], stats_mean[5, 0] - stats_se[5, 0], fc="none", ec="C0", ls="-", alpha=0.3)
# ax2.axhspan(stats_mean[6, 0] + stats_se[6, 0], stats_mean[6, 0] - stats_se[6, 0], fc="none", ec="C0", ls="-", alpha=0.3)
ax2.axhspan(stats_mean[5, 0] + stats_se[5, 0], stats_mean[5, 0] - stats_se[5, 0], fc="gray", alpha=0.3)
ax2.axhspan(stats_mean[6, 0] + stats_se[6, 0], stats_mean[6, 0] - stats_se[6, 0], fc="gray", alpha=0.3)
ax2.axhspan(ground_truth[5, 0] + ground_truth_se[5, 0], ground_truth[5, 0] - ground_truth_se[5, 0], alpha=0.3)
ax2.axhspan(ground_truth[6, 0] + ground_truth_se[6, 0], ground_truth[6, 0] - ground_truth_se[6, 0], alpha=0.3)

ax1.set_ylim(y1_low, y1_high)
ax2.set_ylim(y2_low, y2_high)
ax2.set_xlim(-0.5, 6.5)
ax1.set_yticks(np.arange(y1_low + 0.03, y1_high + 0.01, 0.05))
ax2.set_yticks(np.arange(y2_low, y2_high + 0.01, 0.05))
ax2.set_xticks(
    ticks=np.arange(7),
    labels=["Lure", "Rep Lure", "Diff Item", "Item/Pair", "Pair/Item", "Same Item", "Intact Pair"],
    rotation=30,
    rotation_mode="anchor",
    va="top",
    ha="right",
)
ax1.set_ylabel("HR")
ax2.set_ylabel("FAR")

ax1.spines.bottom.set_visible(False)
ax1.spines.top.set_visible(False)
ax2.spines.top.set_visible(False)
ax1.spines.right.set_visible(False)
ax2.spines.right.set_visible(False)
ax1.tick_params(axis="x", which="both", bottom=False, top=False, labelbottom=False, labeltop=False)
ax2.minorticks_off()

d = 0.5  # proportion of vertical to horizontal extent of the slanted line
kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12, linestyle="none", color="k", mec="k", mew=1, clip_on=False)
ax1.plot(0, 0, transform=ax1.transAxes, **kwargs)
ax2.plot(0, 1, transform=ax2.transAxes, **kwargs)

# if SAVEFIG:
#     ax.set(xlabel=None, ylabel=None)
#     plt.tick_params(labelbottom=False)
#     plt.savefig("simuS1_fig/simuS1_all.pdf")
plt.show()

# %%
# Test 2
y1_low, y1_high = 0.62, 1
y2_low, y2_high = 0, 0.18
range1 = y1_high - y1_low
range2 = y2_high - y2_low

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(6, 8), gridspec_kw={"height_ratios": [range1, range2], "hspace": 0.03})
fig.subplots_adjust(left=0.1, right=0.98, bottom=0.1, top=0.98)

base_xs = np.arange(2, 7)
base_xs_far = np.arange(2)
width = 0.1

# HR
plot_params = {
    "color": "C0",
    "fmt": "o",
    "markersize": 6,
    "markeredgewidth": 1.5,
    "elinewidth": 1.5,
    "capsize": 5,
    "capthick": 1.5,
}
ax1.errorbar(
    x=base_xs - width,
    y=ground_truth[:5, 1],
    yerr=ground_truth_se[:5, 1],
    **plot_params,
)
ax1.errorbar(
    x=base_xs + width,
    y=stats_mean[:5, 1],
    yerr=stats_se[:5, 1],
    markerfacecolor="white",
    **plot_params,
)

# FAR
ax2.errorbar(
    x=base_xs_far - width,
    y=ground_truth[7:4:-1, 1],
    yerr=ground_truth_se[7:4:-1, 1],
    **plot_params,
)
ax2.errorbar(
    x=base_xs_far + width,
    y=stats_mean[7:4:-1, 1],
    yerr=stats_se[7:4:-1, 1],
    markerfacecolor="white",
    **plot_params,
)

# ax2.axhspan(stats_mean[5, 0] + stats_se[5, 0], stats_mean[5, 0] - stats_se[5, 0], fc="none", ec="C0", ls="-", alpha=0.3)
# ax2.axhspan(stats_mean[6, 0] + stats_se[6, 0], stats_mean[6, 0] - stats_se[6, 0], fc="none", ec="C0", ls="-", alpha=0.3)
ax2.axhspan(stats_mean[5, 1] + stats_se[5, 1], stats_mean[5, 1] - stats_se[5, 1], fc="gray", alpha=0.3)
ax2.axhspan(stats_mean[6, 1] + stats_se[6, 1], stats_mean[6, 1] - stats_se[6, 1], fc="gray", alpha=0.3)
ax2.axhspan(ground_truth[5, 1] + ground_truth_se[5, 1], ground_truth[5, 1] - ground_truth_se[5, 1], alpha=0.3)
ax2.axhspan(ground_truth[6, 1] + ground_truth_se[6, 1], ground_truth[6, 1] - ground_truth_se[6, 1], alpha=0.3)

ax1.set_ylim(y1_low, y1_high)
ax2.set_ylim(y2_low, y2_high)
ax2.set_xlim(-0.5, 6.5)
ax1.set_yticks(np.arange(y1_low + 0.03, y1_high + 0.01, 0.05))
ax2.set_yticks(np.arange(y2_low, y2_high + 0.01, 0.05))
ax2.set_xticks(
    ticks=np.arange(7),
    labels=["Lure", "Rep Lure", "Diff Item", "Item/Pair", "Pair/Item", "Same Item", "Intact Pair"],
    rotation=30,
    rotation_mode="anchor",
    va="top",
    ha="right",
)
ax1.set_ylabel("HR")
ax2.set_ylabel("FAR")

ax1.spines.bottom.set_visible(False)
ax1.spines.top.set_visible(False)
ax2.spines.top.set_visible(False)
ax1.spines.right.set_visible(False)
ax2.spines.right.set_visible(False)
ax1.tick_params(axis="x", which="both", bottom=False, top=False, labelbottom=False, labeltop=False)
ax2.minorticks_off()

d = 0.5  # proportion of vertical to horizontal extent of the slanted line
kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12, linestyle="none", color="k", mec="k", mew=1, clip_on=False)
ax1.plot(0, 0, transform=ax1.transAxes, **kwargs)
ax2.plot(0, 1, transform=ax2.transAxes, **kwargs)

# if SAVEFIG:
#     ax.set(xlabel=None, ylabel=None)
#     plt.tick_params(labelbottom=False)
#     plt.savefig("simuS1_fig/simuS1_all.pdf")
plt.show()

# %%
# Q
fig, ax = plt.subplots(figsize=(6, 8))
fig.subplots_adjust(left=0.1, right=0.98, bottom=0.1, top=0.98)

base_xs = np.arange(1, 6)
width = 0.1

plot_params = {
    "color": "C0",
    "fmt": "o",
    "markersize": 6,
    "markeredgewidth": 1.5,
    "elinewidth": 1.5,
    "capsize": 5,
    "capthick": 1.5,
}
ax.errorbar(
    x=base_xs - width,
    y=ground_truth[:5, 2],
    yerr=ground_truth_se[:5, 2],
    **plot_params,
)
ax.errorbar(
    x=base_xs + width,
    y=stats_mean[:5, 2],
    yerr=stats_se[:5, 2],
    markerfacecolor="white",
    **plot_params,
)
ax.errorbar(
    x=-width,
    y=ground_truth[5, 2],
    yerr=ground_truth_se[5, 2],
    **plot_params,
)
ax.errorbar(
    x=width,
    y=stats_mean[5, 2],
    yerr=stats_se[5, 2],
    markerfacecolor="white",
    **plot_params,
)

# setting
ax.set_ylim(0, 1)
ax.set_xlim(-0.5, 5.5)
ax.set_xticks(
    ticks=np.arange(6),
    labels=["Rep Lure", "Diff Item", "Item/Pair", "Pair/Item", "Same Item", "Intact Pair"],
    rotation=30,
    rotation_mode="anchor",
    va="top",
    ha="right",
)
ax.set_yticks(np.arange(0, 1.01, 0.1))
ax.tick_params(axis="y", direction="in")
ax.tick_params(axis="x", direction="in")
ax.set_ylabel("Q")
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

# if SAVEFIG:
#     ax.set(ylabel=None)
#     plt.tick_params(labelbottom=False)
#     plt.savefig("simuS1_fig/simuS1_q.pdf")
plt.show()

# %%
from matplotlib.lines import Line2D

fig2, ax2 = plt.subplots(figsize=(6, 1))
ax2.axis("off")
h_data = Line2D(
    [0],
    [0],
    color="C0",
    marker="o",
    markersize=6,
    markeredgewidth=1.5,
    linestyle="none",
    label="Data",
)
h_model = Line2D(
    [0],
    [0],
    color="C0",
    marker="o",
    markersize=6,
    markeredgewidth=1.5,
    markerfacecolor="white",
    linestyle="none",
    label="CMR-IA",
)
L = ax2.legend(handles=[h_data, h_model], loc="center", ncol=2, fontsize=24)
# if SAVEFIG:
#     plt.savefig("simuS1_fig/simuS1_legend.pdf")

# %%
fig2, ax2 = plt.subplots(figsize=(6, 1))
ax2.set_xticks(
    ticks=np.arange(7),
    labels=["Non-Repeated Lure", "Repeated Lure", "Diff Item", "Item/Pair", "Pair/Item", "Same Item", "Intact Pair"],
    rotation=30,
    rotation_mode="anchor",
    va="top",
    ha="right",
    fontsize=24,
)
ax2.set_ylim(y2_low, y2_high)
ax2.set_yticks(np.arange(y2_low, y2_high + 0.01, 0.05))

# plt.yticks(ticks=np.arange(-0.3, 0.41, 0.1))
# plt.ylabel("S ($^\circ$", fontsize=24, labelpad=15)
# ax2.spines[["right", "top"]].set_visible(False)
# ax2.tick_params(axis="x", which="major", pad=20, length=0)
# plt.ylim([-0.1, 0.1])
# plt.xlim([-0.5, 3.5])
